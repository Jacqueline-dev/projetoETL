# %% [markdown]
# <a href="https://colab.research.google.com/github/Jacqueline-dev/projetoETL/blob/main/limpeza.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/ocorrencia.csv", encoding='cp1252', sep=";", parse_dates=['ocorrencia_dia'], dayfirst=True)
df.tail(5)
# Out:
#       codigo_ocorrencia  codigo_ocorrencia1  codigo_ocorrencia2  \
# 6764              40324               40324               40324
# 6765              39527               39527               39527
# 6766              40211               40211               40211
# 6767              40349               40349               40349
# 6768              40351               40351               40351
#
#       codigo_ocorrencia3  codigo_ocorrencia4 ocorrencia_classificacao  \
# 6764               40324               40324                INCIDENTE
# 6765               39527               39527                 ACIDENTE
# 6766               40211               40211                INCIDENTE
# 6767               40349               40349                INCIDENTE
# 6768               40351               40351                INCIDENTE
#
#      ocorrencia_latitude ocorrencia_longitude   ocorrencia_cidade  \
# 6764                 NaN                  NaN             PELOTAS
# ...

# %%
df.loc[1:3]
# Out:
#    codigo_ocorrencia  codigo_ocorrencia1  codigo_ocorrencia2  \
# 1              81030               81030               81030
# 2              81023               81023               81023
# 3              81029               81029               81029
#
#    codigo_ocorrencia3  codigo_ocorrencia4 ocorrencia_classificacao  \
# 1               81030               81030                INCIDENTE
# 2               81023               81023          INCIDENTE GRAVE
# 3               81029               81029                INCIDENTE
#
#   ocorrencia_latitude ocorrencia_longitude ocorrencia_cidade ocorrencia_uf  \
# 1                 NaN                  NaN           VITÓRIA            ES
# 2                 NaN                  NaN         AMERICANA            SP
# 3                 NaN                  NaN    BELO HORIZONTE            MG
#
#    ... ocorrencia_dia ocorrencia_hora investigacao_aeronave_liberada  \
# 1  ...     2022-10-09        16:20:00                            SIM
# ...

# %%
df.loc[1, 'ocorrencia_cidade']
# Out:
# 'VITÓRIA'

# %%
df.loc[[10,40]]
# Out:
#     codigo_ocorrencia  codigo_ocorrencia1  codigo_ocorrencia2  \
# 10              81017               81017               81017
# 40              80978               80978               80978
#
#     codigo_ocorrencia3  codigo_ocorrencia4 ocorrencia_classificacao  \
# 10               81017               81017          INCIDENTE GRAVE
# 40               80978               80978                 ACIDENTE
#
#    ocorrencia_latitude ocorrencia_longitude      ocorrencia_cidade  \
# 10                 NaN                  NaN                GOIÂNIA
# 40                 NaN                  NaN  SANTA HELENA DE GOIÁS
#
#    ocorrencia_uf  ... ocorrencia_dia ocorrencia_hora  \
# 10            GO  ...     2022-09-30        13:40:00
# 40            GO  ...     2022-09-09        15:40:00
#
#    investigacao_aeronave_liberada investigacao_status  \
# 10                            SIM          FINALIZADA
# 40                            SIM               ATIVA
#
# ...

# %%
df.loc[:,'ocorrencia_cidade']
# Out:
# 0                SÃO PAULO
# 1                  VITÓRIA
# 2                AMERICANA
# 3           BELO HORIZONTE
# 4                   MANAUS
#                ...
# 6764               PELOTAS
# 6765    LUCAS DO RIO VERDE
# 6766        RIO DE JANEIRO
# 6767                 BELÉM
# 6768        RIO DE JANEIRO
# Name: ocorrencia_cidade, Length: 6769, dtype: object

# %%
df.codigo_ocorrencia.is_unique
# Out:
# True

# %%
df.set_index('codigo_ocorrencia', inplace=True)

# %%
df.head()
# Out:
#                    codigo_ocorrencia1  codigo_ocorrencia2  codigo_ocorrencia3  \
# codigo_ocorrencia
# 81027                           81027               81027               81027
# 81030                           81030               81030               81030
# 81023                           81023               81023               81023
# 81029                           81029               81029               81029
# 81025                           81025               81025               81025
#
#                    codigo_ocorrencia4 ocorrencia_classificacao  \
# codigo_ocorrencia
# 81027                           81027          INCIDENTE GRAVE
# 81030                           81030                INCIDENTE
# 81023                           81023          INCIDENTE GRAVE
# 81029                           81029                INCIDENTE
# 81025                           81025                INCIDENTE
#
# ...

# %%
df.loc[81025]
# Out:
# codigo_ocorrencia1                              81025
# codigo_ocorrencia2                              81025
# codigo_ocorrencia3                              81025
# codigo_ocorrencia4                              81025
# ocorrencia_classificacao                    INCIDENTE
# ocorrencia_latitude                               NaN
# ocorrencia_longitude                              NaN
# ocorrencia_cidade                              MANAUS
# ocorrencia_uf                                      AM
# ocorrencia_pais                                BRASIL
# ocorrencia_aerodromo                             SBEG
# ocorrencia_dia                    2022-10-05 00:00:00
# ocorrencia_hora                              20:56:00
# investigacao_aeronave_liberada                    SIM
# investigacao_status                        FINALIZADA
# divulgacao_relatorio_numero                       ***
# divulgacao_relatorio_publicado                    NÃO
# ...

# %%
df.reset_index(drop=True, inplace=True)

# %%
df.head()
# Out:
#    codigo_ocorrencia1  codigo_ocorrencia2  codigo_ocorrencia3  \
# 0               81027               81027               81027
# 1               81030               81030               81030
# 2               81023               81023               81023
# 3               81029               81029               81029
# 4               81025               81025               81025
#
#    codigo_ocorrencia4 ocorrencia_classificacao ocorrencia_latitude  \
# 0               81027          INCIDENTE GRAVE                 NaN
# 1               81030                INCIDENTE                 NaN
# 2               81023          INCIDENTE GRAVE                 NaN
# 3               81029                INCIDENTE                 NaN
# 4               81025                INCIDENTE                 NaN
#
#   ocorrencia_longitude ocorrencia_cidade ocorrencia_uf ocorrencia_pais  ...  \
# 0                  NaN         SÃO PAULO            SP          BRASIL  ...
# ...

# %%
# alterando dados
df.loc[0, 'ocorrencia_aerodromo'] = ''

# %%
df.head(1)
# Out:
#    codigo_ocorrencia1  codigo_ocorrencia2  codigo_ocorrencia3  \
# 0               81027               81027               81027
#
#    codigo_ocorrencia4 ocorrencia_classificacao ocorrencia_latitude  \
# 0               81027          INCIDENTE GRAVE                 NaN
#
#   ocorrencia_longitude ocorrencia_cidade ocorrencia_uf ocorrencia_pais  ...  \
# 0                  NaN         SÃO PAULO            SP          BRASIL  ...
#
#   ocorrencia_dia ocorrencia_hora investigacao_aeronave_liberada  \
# 0     2022-10-09        16:30:00                            SIM
#
#   investigacao_status divulgacao_relatorio_numero  \
# 0               ATIVA                   A DEFINIR
#
#   divulgacao_relatorio_publicado divulgacao_dia_publicacao  \
# 0                            NÃO                       NaN
#
#   total_recomendacoes  total_aeronaves_envolvidas  ocorrencia_saida_pista
# 0                   0                           1                     SIM
#
# [1 rows x 21 columns]

# %%
df.loc[1] = 20

# %%
df.head(2)
# Out:
#    codigo_ocorrencia1  codigo_ocorrencia2  codigo_ocorrencia3  \
# 0               81027               81027               81027
# 1                  20                  20                  20
#
#    codigo_ocorrencia4 ocorrencia_classificacao ocorrencia_latitude  \
# 0               81027          INCIDENTE GRAVE                 NaN
# 1                  20                       20                  20
#
#   ocorrencia_longitude ocorrencia_cidade ocorrencia_uf ocorrencia_pais  ...  \
# 0                  NaN         SÃO PAULO            SP          BRASIL  ...
# 1                   20                20            20              20  ...
#
#         ocorrencia_dia ocorrencia_hora investigacao_aeronave_liberada  \
# 0  2022-10-09 00:00:00        16:30:00                            SIM
# 1                   20              20                             20
#
#   investigacao_status divulgacao_relatorio_numero  \
# 0               ATIVA                   A DEFINIR
# ...

# %%
df.loc[: , 'total_recomendacoes'] = 10

# %%
df
# Out:
#       codigo_ocorrencia1  codigo_ocorrencia2  codigo_ocorrencia3  \
# 0                  81027               81027               81027
# 1                     20                  20                  20
# 2                  81023               81023               81023
# 3                  81029               81029               81029
# 4                  81025               81025               81025
# ...                  ...                 ...                 ...
# 6764               40324               40324               40324
# 6765               39527               39527               39527
# 6766               40211               40211               40211
# 6767               40349               40349               40349
# 6768               40351               40351               40351
#
#       codigo_ocorrencia4 ocorrencia_classificacao ocorrencia_latitude  \
# 0                  81027          INCIDENTE GRAVE                 NaN
# ...

# %%
df['ocorrencia_uf_bkp'] = df.ocorrencia_uf

# %%
df
# Out:
#       codigo_ocorrencia1  codigo_ocorrencia2  codigo_ocorrencia3  \
# 0                  81027               81027               81027
# 1                     20                  20                  20
# 2                  81023               81023               81023
# 3                  81029               81029               81029
# 4                  81025               81025               81025
# ...                  ...                 ...                 ...
# 6764               40324               40324               40324
# 6765               39527               39527               39527
# 6766               40211               40211               40211
# 6767               40349               40349               40349
# 6768               40351               40351               40351
#
#       codigo_ocorrencia4 ocorrencia_classificacao ocorrencia_latitude  \
# 0                  81027          INCIDENTE GRAVE                 NaN
# ...

# %%
df.loc[df.ocorrencia_uf == 'SP', ['ocorrencia_classificacao']] = 'GRAVE'

# %%
df
# Out:
#       codigo_ocorrencia1  codigo_ocorrencia2  codigo_ocorrencia3  \
# 0                  81027               81027               81027
# 1                     20                  20                  20
# 2                  81023               81023               81023
# 3                  81029               81029               81029
# 4                  81025               81025               81025
# ...                  ...                 ...                 ...
# 6764               40324               40324               40324
# 6765               39527               39527               39527
# 6766               40211               40211               40211
# 6767               40349               40349               40349
# 6768               40351               40351               40351
#
#       codigo_ocorrencia4 ocorrencia_classificacao ocorrencia_latitude  \
# 0                  81027                    GRAVE                 NaN
# ...

# %%
df.loc[df.ocorrencia_uf == 'SP']
# Out:
#       codigo_ocorrencia1  codigo_ocorrencia2  codigo_ocorrencia3  \
# 0                  81027               81027               81027
# 2                  81023               81023               81023
# 13                 81003               81003               81003
# 14                 81001               81001               81001
# 18                 80997               80997               80997
# ...                  ...                 ...                 ...
# 6741               39768               39768               39768
# 6743               39847               39847               39847
# 6751               39809               39809               39809
# 6753               39828               39828               39828
# 6759               40069               40069               40069
#
#       codigo_ocorrencia4 ocorrencia_classificacao ocorrencia_latitude  \
# 0                  81027                    GRAVE                 NaN
# ...

# %%
df
# Out:
#       codigo_ocorrencia1  codigo_ocorrencia2  codigo_ocorrencia3  \
# 0                  81027               81027               81027
# 1                     20                  20                  20
# 2                  81023               81023               81023
# 3                  81029               81029               81029
# 4                  81025               81025               81025
# ...                  ...                 ...                 ...
# 6764               40324               40324               40324
# 6765               39527               39527               39527
# 6766               40211               40211               40211
# 6767               40349               40349               40349
# 6768               40351               40351               40351
#
#       codigo_ocorrencia4 ocorrencia_classificacao ocorrencia_latitude  \
# 0                  81027                    GRAVE                 NaN
# ...

# %%
"""
DADOS PARA LIMPAR

ocorrencia_uf
**
ocorrencia_aerodromo
###!
####
****
*****

ocorrencia_hora
NULL

"""

# %%
df.head()
# Out:
#    codigo_ocorrencia1  codigo_ocorrencia2  codigo_ocorrencia3  \
# 0               81027               81027               81027
# 1                  20                  20                  20
# 2               81023               81023               81023
# 3               81029               81029               81029
# 4               81025               81025               81025
#
#    codigo_ocorrencia4 ocorrencia_classificacao ocorrencia_latitude  \
# 0               81027                    GRAVE                 NaN
# 1                  20                       20                  20
# 2               81023                    GRAVE                 NaN
# 3               81029                INCIDENTE                 NaN
# 4               81025                INCIDENTE                 NaN
#
#   ocorrencia_longitude ocorrencia_cidade ocorrencia_uf ocorrencia_pais  ...  \
# 0                  NaN         SÃO PAULO            SP          BRASIL  ...
# ...

# %%
df.loc[df.ocorrencia_aerodromo == '****', ['ocorrencia_aerodromo']] = pd.NA

# %%
df.head()
# Out:
#    codigo_ocorrencia1  codigo_ocorrencia2  codigo_ocorrencia3  \
# 0               81027               81027               81027
# 1                  20                  20                  20
# 2               81023               81023               81023
# 3               81029               81029               81029
# 4               81025               81025               81025
#
#    codigo_ocorrencia4 ocorrencia_classificacao ocorrencia_latitude  \
# 0               81027                    GRAVE                 NaN
# 1                  20                       20                  20
# 2               81023                    GRAVE                 NaN
# 3               81029                INCIDENTE                 NaN
# 4               81025                INCIDENTE                 NaN
#
#   ocorrencia_longitude ocorrencia_cidade ocorrencia_uf ocorrencia_pais  ...  \
# 0                  NaN         SÃO PAULO            SP          BRASIL  ...
# ...

# %%
df.replace(['**', '***', '###!', '####', '****', '*****', 'NULL'], pd.NA, inplace=True)

# %%
df.tail()
# Out:
#       codigo_ocorrencia1  codigo_ocorrencia2  codigo_ocorrencia3  \
# 6764               40324               40324               40324
# 6765               39527               39527               39527
# 6766               40211               40211               40211
# 6767               40349               40349               40349
# 6768               40351               40351               40351
#
#       codigo_ocorrencia4 ocorrencia_classificacao ocorrencia_latitude  \
# 6764               40324                INCIDENTE                 NaN
# 6765               39527                 ACIDENTE    -131.066.666.667
# 6766               40211                INCIDENTE                <NA>
# 6767               40349                INCIDENTE                 NaN
# 6768               40351                INCIDENTE                 NaN
#
#      ocorrencia_longitude   ocorrencia_cidade ocorrencia_uf ocorrencia_pais  \
# ...

# %%
df.isna().sum()
# Out:
# codigo_ocorrencia1                   0
# codigo_ocorrencia2                   0
# codigo_ocorrencia3                   0
# codigo_ocorrencia4                   0
# ocorrencia_classificacao             0
# ocorrencia_latitude               2364
# ocorrencia_longitude              2366
# ocorrencia_cidade                    0
# ocorrencia_uf                        4
# ocorrencia_pais                      0
# ocorrencia_aerodromo              2417
# ocorrencia_dia                       0
# ocorrencia_hora                      2
# investigacao_aeronave_liberada    2307
# investigacao_status                341
# divulgacao_relatorio_numero       4371
# divulgacao_relatorio_publicado       0
# divulgacao_dia_publicacao         4987
# total_recomendacoes                  0
# total_aeronaves_envolvidas           0
# ocorrencia_saida_pista               0
# ocorrencia_uf_bkp                    4
# dtype: int64

# %%
df.isnull().sum()
# Out:
# codigo_ocorrencia1                   0
# codigo_ocorrencia2                   0
# codigo_ocorrencia3                   0
# codigo_ocorrencia4                   0
# ocorrencia_classificacao             0
# ocorrencia_latitude               2364
# ocorrencia_longitude              2366
# ocorrencia_cidade                    0
# ocorrencia_uf                        4
# ocorrencia_pais                      0
# ocorrencia_aerodromo              2417
# ocorrencia_dia                       0
# ocorrencia_hora                      2
# investigacao_aeronave_liberada    2307
# investigacao_status                341
# divulgacao_relatorio_numero       4371
# divulgacao_relatorio_publicado       0
# divulgacao_dia_publicacao         4987
# total_recomendacoes                  0
# total_aeronaves_envolvidas           0
# ocorrencia_saida_pista               0
# ocorrencia_uf_bkp                    4
# dtype: int64

# %%
df.fillna(10, inplace=True)

# %%
df.isnull().sum()
# Out:
# codigo_ocorrencia1                0
# codigo_ocorrencia2                0
# codigo_ocorrencia3                0
# codigo_ocorrencia4                0
# ocorrencia_classificacao          0
# ocorrencia_latitude               0
# ocorrencia_longitude              0
# ocorrencia_cidade                 0
# ocorrencia_uf                     0
# ocorrencia_pais                   0
# ocorrencia_aerodromo              0
# ocorrencia_dia                    0
# ocorrencia_hora                   0
# investigacao_aeronave_liberada    0
# investigacao_status               0
# divulgacao_relatorio_numero       0
# divulgacao_relatorio_publicado    0
# divulgacao_dia_publicacao         0
# total_recomendacoes               0
# total_aeronaves_envolvidas        0
# ocorrencia_saida_pista            0
# ocorrencia_uf_bkp                 0
# dtype: int64

# %%
df.head()
# Out:
#    codigo_ocorrencia1  codigo_ocorrencia2  codigo_ocorrencia3  \
# 0               81027               81027               81027
# 1                  20                  20                  20
# 2               81023               81023               81023
# 3               81029               81029               81029
# 4               81025               81025               81025
#
#    codigo_ocorrencia4 ocorrencia_classificacao ocorrencia_latitude  \
# 0               81027                    GRAVE                  10
# 1                  20                       20                  20
# 2               81023                    GRAVE                  10
# 3               81029                INCIDENTE                  10
# 4               81025                INCIDENTE                  10
#
#   ocorrencia_longitude ocorrencia_cidade ocorrencia_uf ocorrencia_pais  ...  \
# 0                   10         SÃO PAULO            SP          BRASIL  ...
# ...

# %%
df.replace([0], pd.NA, inplace=True)

# %%
df.isnull().sum()
# Out:
# codigo_ocorrencia1                0
# codigo_ocorrencia2                0
# codigo_ocorrencia3                0
# codigo_ocorrencia4                0
# ocorrencia_classificacao          0
# ocorrencia_latitude               0
# ocorrencia_longitude              0
# ocorrencia_cidade                 0
# ocorrencia_uf                     0
# ocorrencia_pais                   0
# ocorrencia_aerodromo              0
# ocorrencia_dia                    0
# ocorrencia_hora                   0
# investigacao_aeronave_liberada    0
# investigacao_status               0
# divulgacao_relatorio_numero       0
# divulgacao_relatorio_publicado    0
# divulgacao_dia_publicacao         0
# total_recomendacoes               0
# total_aeronaves_envolvidas        0
# ocorrencia_saida_pista            0
# ocorrencia_uf_bkp                 0
# dtype: int64

# %%
df.fillna(value={'total_recomendacoes':10}, inplace=True)

# %%
df.isnull().sum()
# Out:
# codigo_ocorrencia1                0
# codigo_ocorrencia2                0
# codigo_ocorrencia3                0
# codigo_ocorrencia4                0
# ocorrencia_classificacao          0
# ocorrencia_latitude               0
# ocorrencia_longitude              0
# ocorrencia_cidade                 0
# ocorrencia_uf                     0
# ocorrencia_pais                   0
# ocorrencia_aerodromo              0
# ocorrencia_dia                    0
# ocorrencia_hora                   0
# investigacao_aeronave_liberada    0
# investigacao_status               0
# divulgacao_relatorio_numero       0
# divulgacao_relatorio_publicado    0
# divulgacao_dia_publicacao         0
# total_recomendacoes               0
# total_aeronaves_envolvidas        0
# ocorrencia_saida_pista            0
# ocorrencia_uf_bkp                 0
# dtype: int64

# %%
df['total_recomendacoes_bkp'] = df.total_recomendacoes

# %%
df.head()
# Out:
#    codigo_ocorrencia1  codigo_ocorrencia2  codigo_ocorrencia3  \
# 0               81027               81027               81027
# 1                  20                  20                  20
# 2               81023               81023               81023
# 3               81029               81029               81029
# 4               81025               81025               81025
#
#    codigo_ocorrencia4 ocorrencia_classificacao ocorrencia_latitude  \
# 0               81027                    GRAVE                  10
# 1                  20                       20                  20
# 2               81023                    GRAVE                  10
# 3               81029                INCIDENTE                  10
# 4               81025                INCIDENTE                  10
#
#   ocorrencia_longitude ocorrencia_cidade ocorrencia_uf ocorrencia_pais  ...  \
# 0                   10         SÃO PAULO            SP          BRASIL  ...
# ...

# %%
df.drop(['total_recomendacoes_bkp'], axis=1, inplace=True)

# %%
df.head()
# Out:
#    codigo_ocorrencia1  codigo_ocorrencia2  codigo_ocorrencia3  \
# 0               81027               81027               81027
# 1                  20                  20                  20
# 2               81023               81023               81023
# 3               81029               81029               81029
# 4               81025               81025               81025
#
#    codigo_ocorrencia4 ocorrencia_classificacao ocorrencia_latitude  \
# 0               81027                    GRAVE                  10
# 1                  20                       20                  20
# 2               81023                    GRAVE                  10
# 3               81029                INCIDENTE                  10
# 4               81025                INCIDENTE                  10
#
#   ocorrencia_longitude ocorrencia_cidade ocorrencia_uf ocorrencia_pais  ...  \
# 0                   10         SÃO PAULO            SP          BRASIL  ...
# ...

# %%
df.dropna()
# Out:
#       codigo_ocorrencia1  codigo_ocorrencia2  codigo_ocorrencia3  \
# 0                  81027               81027               81027
# 1                     20                  20                  20
# 2                  81023               81023               81023
# 3                  81029               81029               81029
# 4                  81025               81025               81025
# ...                  ...                 ...                 ...
# 6764               40324               40324               40324
# 6765               39527               39527               39527
# 6766               40211               40211               40211
# 6767               40349               40349               40349
# 6768               40351               40351               40351
#
#       codigo_ocorrencia4 ocorrencia_classificacao ocorrencia_latitude  \
# 0                  81027                    GRAVE                  10
# ...

# %%
df
# Out:
#       codigo_ocorrencia1  codigo_ocorrencia2  codigo_ocorrencia3  \
# 0                  81027               81027               81027
# 1                     20                  20                  20
# 2                  81023               81023               81023
# 3                  81029               81029               81029
# 4                  81025               81025               81025
# ...                  ...                 ...                 ...
# 6764               40324               40324               40324
# 6765               39527               39527               39527
# 6766               40211               40211               40211
# 6767               40349               40349               40349
# 6768               40351               40351               40351
#
#       codigo_ocorrencia4 ocorrencia_classificacao ocorrencia_latitude  \
# 0                  81027                    GRAVE                  10
# ...

# %%
df.dropna(subset=['ocorrencia_uf'])
# Out:
#       codigo_ocorrencia1  codigo_ocorrencia2  codigo_ocorrencia3  \
# 0                  81027               81027               81027
# 1                     20                  20                  20
# 2                  81023               81023               81023
# 3                  81029               81029               81029
# 4                  81025               81025               81025
# ...                  ...                 ...                 ...
# 6764               40324               40324               40324
# 6765               39527               39527               39527
# 6766               40211               40211               40211
# 6767               40349               40349               40349
# 6768               40351               40351               40351
#
#       codigo_ocorrencia4 ocorrencia_classificacao ocorrencia_latitude  \
# 0                  81027                    GRAVE                  10
# ...

# %%
df.drop_duplicates(inplace=True)

# %%
df
# Out:
#       codigo_ocorrencia1  codigo_ocorrencia2  codigo_ocorrencia3  \
# 0                  81027               81027               81027
# 1                     20                  20                  20
# 2                  81023               81023               81023
# 3                  81029               81029               81029
# 4                  81025               81025               81025
# ...                  ...                 ...                 ...
# 6764               40324               40324               40324
# 6765               39527               39527               39527
# 6766               40211               40211               40211
# 6767               40349               40349               40349
# 6768               40351               40351               40351
#
#       codigo_ocorrencia4 ocorrencia_classificacao ocorrencia_latitude  \
# 0                  81027                    GRAVE                  10
# ...
